# %% [markdown]
# <table>
#     <tr>
#         <td><img src="./imagenes/Macc.png" width="400"/></td>
#         <td>&nbsp;</td>
#         <td>
#             <h1 style="color:blue;text-align:left">Inteligencia Artificial</h1></td>
#         <td>
#             <table><tr>
#             <tp><p style="font-size:150%;text-align:center">Notebook</p></tp>
#             <tp><p style="font-size:150%;text-align:center">Búsqueda en espacios de estados</p></tp>
#             </tr></table>
#         </td>
#     </tr>
# </table>
#
# ---

# %%
from AmbientesMP import *
from random import choice
import numpy as np

# %% [markdown]
# ## El vendedor viajero

# %%
prob = Vendedor('Chapinero')
#s = prob.estado_inicial # los estados son listas de localidades
prob.pintar_estado(s)

# %%
acciones = prob.acciones_aplicables(s)
a = choice(acciones)
s1 = prob.transicion(s, a)
acciones = prob.acciones_aplicables(s1)
a1 = choice(acciones)
s2 = prob.transicion(s1, a1)
prob.pintar_camino([s,s1,s2])

# %%
prob.test_objetivo(s2)
# Out:
# False

# %%
def primero_en_profundidad(problema):

    estado = problema.estado_inicial
    if problema.test_objetivo(estado): return estado
    frontera = []
    frontera.append(estado)
    while len(frontera) > 0:
        estado = frontera.pop()
        for accion in problema.acciones_aplicables(estado):
            hijo = problema.transicion(estado, accion)
            if problema.test_objetivo(hijo):return hijo 
            frontera.append(hijo)
    return None

# %%
prob = Vendedor('Chapinero')
estado_sol = primero_en_profundidad(prob)
prob.pintar_estado(estado_sol)

# %%
def avara(prob):
    min_llave_valor = lambda s, prob_rutas: min(prob_rutas[s].items(), key=lambda x: x[1])
    s = prob.estado_inicial
    costo = 0
    camino = [s[0]]
    while not(prob.test_objetivo(camino)):
        llave_valor_minimo = min_llave_valor(camino[-1], prob.rutas)
        local = llave_valor_minimo[0]
        
        camino = prob.transicion(camino,local)
        print (camino)
        #prob.pintar_camino(camino)
        costo += llave_valor_minimo[1] 
    return camino, costo

# %%
prob = Vendedor('Chapinero')
camino, costo = avara(prob)
prob.pintar_estado(camino)
# Out:
# ['Chapinero', 'Barrios Unidos']
# ['Chapinero', 'Barrios Unidos', 'Chapinero']
# ['Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos']
# ['Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero']
# ['Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos']
# ['Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero']
# ['Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos']
# ['Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero']
# ['Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos', 'Chapinero', 'Barrios Unidos']
# ...

# %%
camino
# Out:
# ['Chapinero']

# %%
s = prob.estado_inicial
local = prob.acciones_aplicables(s)
costos = []

mini = np.inf
localidad = 0
for i in local:
    val = prob.rutas[s[0]][i]
    if val < mini:
        mini  = val
        localidad = i
print (localidad, mini)
# Out:
# Barrios Unidos 4.6

# %%
s[0]
# Out:
# 'Chapinero'

# %%
prob.rutas[s[0]]
# Out:
# {'Usaquen': 7.5,
#  'Santa Fe': 6.2,
#  'San Cristobal': 13.9,
#  'Usme': 26.2,
#  'Tunjuelito': 18.1,
#  'Bosa': 20.3,
#  'Kennedy': 14.8,
#  'Fontibon': 15.2,
#  'Engativa': 10.5,
#  'Suba': 9.8,
#  'Barrios Unidos': 4.6}

# %%
min_llave_valor = lambda s, prob_rutas: min(prob_rutas[s].items(), key=lambda x: x[1])

# Ejemplo de uso
llave_valor_minimo = min_llave_valor(s[0], prob.rutas)
print(f"La llave con el valor mínimo en el diccionario es: {llave_valor_minimo[0]}")
print(f"El valor mínimo es: {llave_valor_minimo[1]}")
# Out:
# La llave con el valor mínimo en el diccionario es: Barrios Unidos
# El valor mínimo es: 4.6
